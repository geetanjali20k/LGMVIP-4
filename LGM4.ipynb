# %% [markdown]
# # LetsGrowMore - Data Science Internship
# ## Task 4: Image to Pencil sketch with Python
# ### Author: Geetanjali Kotkar
# - Here we need to read the image in RBG format and then convert it to a grayscale image. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image.
#
# - Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ![butterfly.jpeg](attachment:butterfly.jpeg)

# %%
# !pip install opencv-python

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Read the Image

# %%
image = cv2.imread("C:\\Users\\kotka\\OneDrive\\Pictures\\butterfly.jpeg")
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=954x799 at 0x2B9C9D7AFD0>

# %% [markdown]
# ## Convert image to grayscale image

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=954x799 at 0x2B9C9D67C70>

# %% [markdown]
# ## Invert greyscale image to inverted image

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=954x799 at 0x2B9CBB2CFA0>

# %% [markdown]
# ## Inverted image to blurry image

# %%
blurr_image = cv2.GaussianBlur(inverted_image,(21,21),0)
display(Image.fromarray(blurr_image))
# Out:
# <PIL.Image.Image image mode=L size=954x799 at 0x2B9C8547700>

# %% [markdown]
# ## Create the pencil sketch by mixing grayscale image with blurry image

# %%
inverted_blurr = cv2.bitwise_not(blurr_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurr, scale= 250)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=954x799 at 0x2B9C9CFA220>

# %% [markdown]
# - Finally here is image to pencil sketch image.
# ## Thank you !
